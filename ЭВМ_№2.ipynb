# %%
import numpy as np
import math
import matplotlib.pyplot as plt

T = 3.1
eps = 0.01
h = 0.001
N = int(T/h)

def f1(x1, x2, p1, p2, t):
    return x2

def f2(x1, x2, p1, p2, t):
  if(p2>=2):
    return 1
  elif(p2<=-2):
    return -1
  else:
    return p2/2

def f3(x1, x2, p1, p2, t):
  return -2*x1

def f4(x1, x2, p1, p2, t):
  return -p1


def RK4(x1_0, x2_0, p1_0, p2_0):

  t = 0
  x1 = 0
  x2 = 1
  p1 = p1_0
  p2 = p2_0

  X1 = []
  X2 = []
  P1 = []
  P2 = []

  for i in range(N+1):

    t = h*i

    k11 = f1(x1, x2, p1, p2, t)
    k12 = f2(x1, x2, p1, p2, t)
    k13 = f3(x1, x2, p1, p2, t)
    k14 = f4(x1, x2, p1, p2, t)

    k21 = f1(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k22 = f2(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k23 = f3(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k24 = f4(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))

    k31 = f1(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k32 = f2(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k33 = f3(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k34 = f4(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))

    k41 = f1(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k42 = f2(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k43 = f3(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k44 = f4(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)

    x1 += (h/6)*(k11+2*k21+2*k31+k41)
    x2 += (h/6)*(k12+2*k22+2*k32+k42)
    p1 += (h/6)*(k13+2*k23+2*k33+k43)
    p2 += (h/6)*(k14+2*k24+2*k34+k44)

    X1.append(x1)
  return X1

def RK4p(x1_0, x2_0, p1_0, p2_0):

  t = 0
  x1 = 0
  x2 = 1
  p1 = p1_0
  p2 = p2_0

  X1 = []
  P2 = []

  for i in range(N+1):

    t = h*i

    k11 = f1(x1, x2, p1, p2, t)
    k12 = f2(x1, x2, p1, p2, t)
    k13 = f3(x1, x2, p1, p2, t)
    k14 = f4(x1, x2, p1, p2, t)

    k21 = f1(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k22 = f2(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k23 = f3(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k24 = f4(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))

    k31 = f1(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k32 = f2(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k33 = f3(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k34 = f4(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))

    k41 = f1(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k42 = f2(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k43 = f3(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k44 = f4(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)

    x1 += (h/6)*(k11+2*k21+2*k31+k41)
    x2 += (h/6)*(k12+2*k22+2*k32+k42)
    p1 += (h/6)*(k13+2*k23+2*k33+k43)
    p2 += (h/6)*(k14+2*k24+2*k34+k44)

    P2.append(p2)

  return P2

#начальные условия p1_0 = 1
#начальные условия p1_0 = 1

def shooting(x1_0, x2_0):
  p2_0 = 1
  temp = RK4(0, 1, 1, p2_0)
  for i in range(N):
    temp = RK4(0, 1, 1, p2_0)
    print(temp[N], p2_0)
    p2_0 *= 1/2
  temp = RK4(0, 1, 1, 0)
  print(temp[N]-1)
  return p2_0





def shooting2(x1_0, x2_0):
  p1_0 = -0.5
  temp = RK4(0, 1, p1_0, 0)
  #print(temp[N])
  while abs(temp[N]) > eps:
    p1_0 += h
    temp = RK4p(0, 1, p1_0, 0)
    #print(temp[N], p1_0)
  return p1_0


def shooting(x1_0, x2_0):
  p1_0 = shooting2(x1_0, x2_0)
  p2_0 = -0.01
  temp = RK4(0, 1, p1_0, p2_0)
  print(temp[N])
  while abs(temp[N]) > eps:
    p2_0 -= 2*h
    temp = RK4(0, 1, p1_0, p2_0)
    print(temp[N], p2_0)
  return p1_0, p2_0


x = []
for i in range(N+1):
  x.append(h*i)


#A = RK4(0, 1, -0.5628387435771603, 0)
#print(A)
#plt.plot(x,A)

#print(shooting(0, 1)[0])
#print(shooting(0, 1)[1])

#print(shooting(0, 1))

#A = RK4(0, 1, shooting2(0, 1), -1)
for i in range(5):
  #for j in range(5):
  A = RK4(0, 1, -30.922572508726564-i*0.1,  -114.77346187983157)
  plt.plot(x,A)

#shooting22(0, 1) p1_0 = 0.2800000000000004
#eps = 0.1 T = 1,

# %%
#простая итерация

eps = 0.01
max_it = 10**3

def F(y1, y2):
  X = RK4(0, 1, y1, y2)
  P = RK4p(0, 1, y1, y2)
  F = [X[N], P[N]]
  return F


def simple_it(y1_0, y2_0, t1, t2):
  y1_1 = y1_0
  y2_1 = y2_0
  k = 0
  for i in range(max_it):
    F1 = F(y1_1, y2_1)
    y1_2 = y1_1 + t1*F1[0]
    y2_2 = y2_1 + t2*F1[1]
    F2 = F(y1_2, y2_2)
    if(F2[0]**2+F2[1]**2<eps**2):
      break
    if(F2[0]**2+F2[1]**2<F1[0]**2+F1[1]**2):
      t1 = t1
      t2 = t2
    else:
      if(t1>0):
        t1 = -t1
      elif(t1<0):
        t1 = (-1/2)*t1
      if(t2>0):
        t2 = -t2
      elif(t2<0):
        t2 = (-1/2)*t2
    y1_1 = y1_2
    y2_1 = y2_2
    #print(F(y1_1, y2_1))
    k+=1
  print(k)
  Y = [y1_1, y2_1]
  return Y
#начальные условия для T = 10 (x1, x2) = (-32.0633036864673, -120.17935359941089), (t1, t2) = (1, 1)
Beta = simple_it(-32.0633036864673, -120.17935359941089, 1, 1)
print(F(0, 0))
print(F(Beta[0], Beta[1]))
A = RK4(0, 1, Beta[0], Beta[1])
plt.title("h = 0.001, T = 10")
plt.plot(x,A)
print(Beta[0], Beta[1])
# Out:
# 72
# [46.67467263315353, 654.4035294376445]
# [0.0018447817978320736, 0.010128294376892256]
# -30.922572508726564 -114.77346187983157

# %%
eps = 0.01
max_it = 10**3

def F(y1, y2):
  X = RK4(0, 1, y1, y2)
  P = RK4p(0, 1, y1, y2)
  F = [X[N], P[N]]
  return F


def simple_it(y1_0, y2_0, t1, t2):
  y1_1 = y1_0
  y2_1 = y2_0
  k = 0
  for i in range(max_it):
    F1 = F(y1_1, y2_1)
    y1_2 = y1_1 + t1*F1[0]
    y2_2 = y2_1 + t2*F1[1]
    F2 = F(y1_2, y2_2)
    if(F2[0]**2+F2[1]**2<eps**2):
      break
    if(F2[0]**2+F2[1]**2<F1[0]**2+F1[1]**2):
      t1 = t1
      t2 = t2
    else:
      if(t1>0):
        t1 = -t1
      elif(t1<0):
        t1 = (-1/2)*t1
      if(t2>0):
        t2 = -t2
      elif(t2<0):
        t2 = (-1/2)*t2
    y1_1 = y1_2
    y2_1 = y2_2
    #print(F(y1_1, y2_1))
    k+=1
  print(k)
  Y = [y1_1, y2_1]
  return Y
N = int(3/h)
x = []
for i in range(N+1):
  x.append(h*i)
#начальные условия для T = 10 (x1, x2) = (-32.0633036864673, -120.17935359941089), (t1, t2) = (1, 1)
#Beta = simple_it(-32.0633036864673, -120.17935359941089, 1, 1)
print(F(0, 0))
#print(F(Beta[0], Beta[1]))
#A = RK4(0, 1, Beta[0], Beta[1])
A = RK4(0, 1, 1, 1)
for i in range(N+1):
  A[i] = (1/10**2)*A[i]*(A[i]-A[N])**2
plt.plot(x,A)
A1 = A

#print(Beta[0], Beta[1])
# Out:
# [4.280984656413265, 8.078493589780647]

# %%
A = RK4(0, 1, 1, 1)
for i in range(N+1):
  A[i] = (1/10**2)*A[i]*(A[i]-A[N]- 0.1)**2
plt.plot(x,A)
A2 = A

A = RK4(0, 1, 1, 1)
for i in range(N+1):
  A[i] = (1/10**2)*A[i]*(A[i]-A[N]- 0.2)**2
plt.plot(x,A)
A3 = A

A = RK4(0, 1, 1, 1)
for i in range(N+1):
  A[i] = (1/10**2)*A[i]*(A[i]-A[N]- 0.3)**2
plt.plot(x,A)
A4 = A

# %%
T = 10
eps = 0.1
h = 0.01
N = int(T/h)

def f1(x1, x2, t):
    return np.sin(t)

def f2(x1, x2, t):
    return x1


    k11 = f1(x1, x2, p1, p2, t)
    k12 = f2(x1, x2, p1, p2, t)
    k13 = f3(x1, x2, p1, p2, t)
    k14 = f4(x1, x2, p1, p2, t)

    k21 = f1(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k22 = f2(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k23 = f3(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k24 = f4(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))

    k31 = f1(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k32 = f2(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k33 = f3(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k34 = f4(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))

    k41 = f1(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k42 = f2(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k43 = f3(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k44 = f4(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)

    x1 += (h/6)*(k11+2*k21+2*k31+k41)
    x2 += (h/6)*(k12+2*k22+2*k32+k42)
    p1 += (h/6)*(k13+2*k23+2*k33+k43)
    p2 += (h/6)*(k14+2*k24+2*k34+k44)



def RK4(x1_0, x2_0):
  t = 0
  x1 = x1_0
  x2 = x2_0
  X1 = []

  for i in range(N+1):

    t = h*i

    k11 = f1(x1, x2, t)
    k12 = f1(x1, x2, t)

    k2 = f1(x1 + k1*(h/2), t + (h/2))

    k3 = f1(x1+k2*(h/2), t + (h/2))

    k4 = f1(x1 + k3*h, t + h)

    x1 += (h/6)*(k1+2*k2+2*k3+k4)

    X1.append(x1)

  return X1

t = []
e = []
for i in range(N+1):
  t.append(i*h)
  e.append((2-np.cos(i*h)))
plt.plot()
plt.plot(t, RK4(1))
#plt.plot(t, e)

T = 10
eps = 0.01
h = 0.001
N = int(T/h)

def f1(x1, x2, p1, p2, t):
    return x2

def f2(x1, x2, p1, p2, t):
  if(p2>=2):
    return 1
  elif(p2<=-2):
    return -1
  else:
    return p2/2

def f3(x1, x2, p1, p2, t):
  return -2*x1

def f4(x1, x2, p1, p2, t):
  return -p1


def RK4(x1_0, x2_0, p1_0, p2_0):

  t = 0
  x1 = 0
  x2 = 1
  p1 = p1_0
  p2 = p2_0

  X1 = []
  X2 = []
  P1 = []
  P2 = []

  for i in range(N+1):

    t = h*i

    k11 = f1(x1, x2, p1, p2, t)
    k12 = f2(x1, x2, p1, p2, t)
    k13 = f3(x1, x2, p1, p2, t)
    k14 = f4(x1, x2, p1, p2, t)

    k21 = f1(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k22 = f2(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k23 = f3(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k24 = f4(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))

    k31 = f1(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k32 = f2(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k33 = f3(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k34 = f4(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))

    k41 = f1(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k42 = f2(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k43 = f3(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k44 = f4(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)

    x1 += (h/6)*(k11+2*k21+2*k31+k41)
    x2 += (h/6)*(k12+2*k22+2*k32+k42)
    p1 += (h/6)*(k13+2*k23+2*k33+k43)
    p2 += (h/6)*(k14+2*k24+2*k34+k44)

    X1.append(x1)
  return X1

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

eps = 0.01
h = 0.0001
N = int(T/h)

def f1(x1, x2, p1, p2, t):
    return x2

def f2(x1, x2, p1, p2, t):
  if(p2>=2):
    return 1
  elif(p2<=-2):
    return -1
  else:
    return p2/2

def f3(x1, x2, p1, p2, t):
  return -2*x1

def f4(x1, x2, p1, p2, t):
  return -p1

def RK4(p1_0, p2_0, T):

  N = int(T/h)
  t = 0
  x1 = 0
  x2 = 1
  p1 = p1_0
  p2 = p2_0

  X1 = []
  P2 = []

  for i in range(N+1):

    t = h*i

    k11 = f1(x1, x2, p1, p2, t)
    k12 = f2(x1, x2, p1, p2, t)
    k13 = f3(x1, x2, p1, p2, t)
    k14 = f4(x1, x2, p1, p2, t)

    k21 = f1(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k22 = f2(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k23 = f3(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k24 = f4(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))

    k31 = f1(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k32 = f2(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k33 = f3(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k34 = f4(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))

    k41 = f1(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k42 = f2(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k43 = f3(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k44 = f4(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)

    x1 += (h/6)*(k11+2*k21+2*k31+k41)
    x2 += (h/6)*(k12+2*k22+2*k32+k42)
    p1 += (h/6)*(k13+2*k23+2*k33+k43)
    p2 += (h/6)*(k14+2*k24+2*k34+k44)

    X1.append(x1)
    P2.append(p2)
  return [X1, P2]

max_it = 10**3

def F(p1_0, p2_0, T):
  N = int(T/h)
  X1 = RK4(p1_0, p2_0, T)[0]
  P2 = RK4(p1_0, p2_0, T)[1]
  F = [X1[N], P2[N]]
  return F



def J(p1, p2, T):
    N = int(T/h)
    j=np.array([[0,0],[0,0]],float)
    j_1 = RK4(p1+h, p2, T)[0]
    j_2 = RK4(p1-h, p2, T)[0]
    j_3 = RK4(p1+h, p2, T)[1]
    j_4 = RK4(p1-h, p2, T)[1]
    j_5 = RK4(p1, p2+h, T)[0]
    j_6 = RK4(p1, p2-h, T)[0]
    j_7 = RK4(p1, p2+h, T)[1]
    j_8 = RK4(p1, p2-h, T)[1]

    j[0][0]=(j_1[N]-j_2[N])/(2*h)
    j[1][0]=(j_3[N]-j_4[N])/(2*h)
    j[0][1]=(j_5[N]-j_6[N])/(2*h)
    j[1][1]=(j_7[N]-j_8[N])/(2*h)

    return j

max_it = 10**3

def Newton(p1_0, p2_0, T):
  p1 = p1_0
  p2 = p2_0
  for i in range (max_it):
    #print(J(p1, p2, T))
    #print(np.linalg.norm(F(p1,p2, T)))
    P = np.linalg.inv(J(p1, p2, T))
    f = F(p1,p2, T)
    p1-=(P@f)[0]
    p2-=(P@f)[1]
    err = np.linalg.norm(F(p1,p2, T))
    if(err < eps):
      break
    #print(p1, p2)
  return [p1, p2]

T = 2
N = int(T/h)
P = Newton(0, 0, T)
X = RK4(P[0], P[1], T)[0]
t = np.zeros(N+1)
for i in range(N+1):
  t[i] = h*i
plt.plot(t, X)

# %%
T = 20
h = 0.01
N = int(T/h)
P = Newton(0, 0, T)
X = RK4(P[0], P[1], T)[0]
t = np.zeros(N+1)
for i in range(N+1):
  t[i] = h*i
plt.title("T = 3")
plt.plot(t, X, label='h = 0.1')

h = 0.005
N = int(T/h)
P = Newton(0, 0, T)
X = RK4(P[0], P[1], T)[0]
t = np.zeros(N+1)
for i in range(N+1):
  t[i] = h*i
plt.title("T = 2")
plt.plot(t, X, label='h = 0.01')

h = 0.001
N = int(T/h)
P = Newton(0, 0, T)
X = RK4(P[0], P[1], T)[0]
t = np.zeros(N+1)
for i in range(N+1):
  t[i] = h*i
plt.title("x(t), T = 20")
plt.plot(t, X, label='h = 0.001')
plt.legend()

# %%
T = 20
h = 0.001
N = int(T/h)
P = Newton(1, 1, T)
X = RK4(P[0], P[1], T)[0]
t = np.zeros(N+1)
for i in range(N+1):
  t[i] = h*i

plt.title("x(t), T = 20")
plt.plot(t, X, label='h = 0.001')
plt.legend()

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

eps = 0.01
h = 0.0001

def f1(x1, x2, p1, p2, t):
    return x2

def f2(x1, x2, p1, p2, t):
    return p2/2

def f3(x1, x2, p1, p2, t):
  return -2*x1

def f4(x1, x2, p1, p2, t):
  return -p1

def RK4(p1_0, p2_0, T):

  N = int(T/h)
  t = 0
  x1 = 0
  x2 = 1
  p1 = p1_0
  p2 = p2_0

  X1 = []
  P2 = []

  for i in range(N+1):

    t = h*i

    k11 = f1(x1, x2, p1, p2, t)
    k12 = f2(x1, x2, p1, p2, t)
    k13 = f3(x1, x2, p1, p2, t)
    k14 = f4(x1, x2, p1, p2, t)

    k21 = f1(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k22 = f2(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k23 = f3(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k24 = f4(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))

    k31 = f1(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k32 = f2(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k33 = f3(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k34 = f4(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))

    k41 = f1(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k42 = f2(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k43 = f3(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k44 = f4(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)

    x1 += (h/6)*(k11+2*k21+2*k31+k41)
    x2 += (h/6)*(k12+2*k22+2*k32+k42)
    p1 += (h/6)*(k13+2*k23+2*k33+k43)
    p2 += (h/6)*(k14+2*k24+2*k34+k44)

    X1.append(x1)
    P2.append(p2)
  return [X1, P2]

max_it = 10**3

def F(p1_0, p2_0, T):
  N = int(T/h)
  X1 = RK4(p1_0, p2_0, T)[0]
  P2 = RK4(p1_0, p2_0, T)[1]
  F = [X1[N], P2[N]]
  return F



def J(p1, p2, T):
    N = int(T/h)
    j=np.array([[0,0],[0,0]],float)
    j_1 = RK4(p1+h, p2, T)[0]
    j_2 = RK4(p1-h, p2, T)[0]
    j_3 = RK4(p1+h, p2, T)[1]
    j_4 = RK4(p1-h, p2, T)[1]
    j_5 = RK4(p1, p2+h, T)[0]
    j_6 = RK4(p1, p2-h, T)[0]
    j_7 = RK4(p1, p2+h, T)[1]
    j_8 = RK4(p1, p2-h, T)[1]

    j[0][0]=(j_1[N]-j_2[N])/(2*h)
    j[1][0]=(j_3[N]-j_4[N])/(2*h)
    j[0][1]=(j_5[N]-j_6[N])/(2*h)
    j[1][1]=(j_7[N]-j_8[N])/(2*h)

    return j


max_it = 10**3

def Newton(p1_0, p2_0, T):
  p1 = p1_0
  p2 = p2_0
  for i in range (max_it):
    #print(J(p1, p2, T))
    #print(np.linalg.norm(F(p1,p2, T)))
    P = np.linalg.inv(J(p1, p2, T))
    f = F(p1,p2, T)
    p1-=(P@f)[0]
    p2-=(P@f)[1]
    err = np.linalg.norm(F(p1,p2, T))
    if(err < eps):
      break
    #print(p1, p2)
  return [p1, p2]

T = 2
N = int(T/h)
P = Newton(0, 0, T)
X11 = RK4(P[0], P[1], T)[0]
t = np.zeros(N+1)
for i in range(N+1):
  t[i] = h*i
plt.title('T=1')
plt.plot(t, X11)

for i in range(len(X11)):
  X11[i] = X11[i]/(0.5/0.4)


T = 2
N = int(T/h)
P = Newton(0, 0, T)
X12 = RK4(P[0], P[1], T)[0]
t = np.zeros(N+1)
for i in range(N+1):
  t[i] = h*i
plt.title('T=1')
plt.plot(t, X11)

for i in range(len(X11)):
  X12[i] = X12[i]/(0.45/0.4)

# %%
import numpy as np
import math
import matplotlib.pyplot as plt

eps = 0.01
h = 0.0001

def f1(x1, x2, p1, p2, t):
    return x2

def f2(x1, x2, p1, p2, t):
  if(p2>10):
    return 10/2
  if(p2<-10):
    return -10/2
  else:
    return p2/2

def f3(x1, x2, p1, p2, t):
  return -2*x1

def f4(x1, x2, p1, p2, t):
  return -p1

def RK4(p1_0, p2_0, T):

  N = int(T/h)
  t = 0
  x1 = 0
  x2 = 1
  p1 = p1_0
  p2 = p2_0

  X1 = []
  P2 = []

  for i in range(N+1):

    t = h*i

    k11 = f1(x1, x2, p1, p2, t)
    k12 = f2(x1, x2, p1, p2, t)
    k13 = f3(x1, x2, p1, p2, t)
    k14 = f4(x1, x2, p1, p2, t)

    k21 = f1(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k22 = f2(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k23 = f3(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))
    k24 = f4(x1 + k11*(h/2), x2+k12*(h/2), p1 + k13*(h/2), p2 + k14*(h/2), t + (h/2))

    k31 = f1(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k32 = f2(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k33 = f3(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))
    k34 = f4(x1+k21*(h/2), x2 + k22*(h/2), p1 + k23*(h/2), p2 + k24*(h/2), t + (h/2))

    k41 = f1(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k42 = f2(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k43 = f3(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)
    k44 = f4(x1 + k31*h, x2 + k32*h, p1_0 + k33*h, p2 + k34*h, t + h)

    x1 += (h/6)*(k11+2*k21+2*k31+k41)
    x2 += (h/6)*(k12+2*k22+2*k32+k42)
    p1 += (h/6)*(k13+2*k23+2*k33+k43)
    p2 += (h/6)*(k14+2*k24+2*k34+k44)

    X1.append(x1)
    P2.append(p2)
  return [X1, P2]

max_it = 10**3

def F(p1_0, p2_0, T):
  N = int(T/h)
  X1 = RK4(p1_0, p2_0, T)[0]
  P2 = RK4(p1_0, p2_0, T)[1]
  F = [X1[N], P2[N]]
  return F



def J(p1, p2, T):
    N = int(T/h)
    j=np.array([[0,0],[0,0]],float)
    j_1 = RK4(p1+h, p2, T)[0]
    j_2 = RK4(p1-h, p2, T)[0]
    j_3 = RK4(p1+h, p2, T)[1]
    j_4 = RK4(p1-h, p2, T)[1]
    j_5 = RK4(p1, p2+h, T)[0]
    j_6 = RK4(p1, p2-h, T)[0]
    j_7 = RK4(p1, p2+h, T)[1]
    j_8 = RK4(p1, p2-h, T)[1]

    j[0][0]=(j_1[N]-j_2[N])/(2*h)
    j[1][0]=(j_3[N]-j_4[N])/(2*h)
    j[0][1]=(j_5[N]-j_6[N])/(2*h)
    j[1][1]=(j_7[N]-j_8[N])/(2*h)

    return j


max_it = 10**3

def Newton(p1_0, p2_0, T):
  p1 = p1_0
  p2 = p2_0
  for i in range (max_it):
    #print(J(p1, p2, T))
    #print(np.linalg.norm(F(p1,p2, T)))
    P = np.linalg.inv(J(p1, p2, T))
    f = F(p1,p2, T)
    p1-=(P@f)[0]
    p2-=(P@f)[1]
    err = np.linalg.norm(F(p1,p2, T))
    if(err < eps):
      break
    #print(p1, p2)
  return [p1, p2]

T = 2
N = int(T/h)
P = Newton(0, 0, T)
X = RK4(P[0], P[1], T)[0]
t = np.zeros(N+1)
for i in range(N+1):
  t[i] = h*i
plt.title("x(t), T = 2")

plt.plot(t, X, label = '9')
plt.plot(t, X11, label = 'inf')
plt.plot(t, X12, label = '10')
plt.legend()
